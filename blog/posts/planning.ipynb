# %% [markdown]
# Integrated Energy Planning

# %% [markdown]
# Bruegel: https://www.bruegel.org/policy-brief/better-coordination-for-a-more-efficient-european-energy-system
#
# RAP: https://www.raponline.org/knowledge-center/planning-for-success-how-integrated-energy-planning-can-help-electrification-europe/
#
# Agora Energiewende: https://www.agora-energiewende.org/publications/designing-energy-infrastructure-for-a-climate-neutral-europe
#
# To address this, Agora Energiewende together with
#
# - Forum Energii
# - IDDRI
# - ECCO
# - Energy Policy Group
#
# commissioned
#
# - Fraunhofer IEG
# - Fraunhofer ISI
# - d-fine
#
# to carry out a comprehensive modelling
# of Europe’s energy infrastructure needs. Using
# conservative parameters to ensure robust insights,
# the modelling identifies where to prioritise investment for an efficient, coordinated and cost-effective
# energy transition.
# Building on the Fraunhofer and d-fine study,
# our Impulse paper sets out priorities, planning
# approaches and concrete recommendations to guide
# infrastructure development across Europe. It aims
# to inform ongoing discussions among policymakers,
# stakeholders and planners on how best to deliver
# the infrastructure underpinning Europe’s climate,
# security and competitiveness goals.

# %% [markdown]
# Ember: https://ember-energy.org/latest-insights/grids-policy-package-embers-input-to-the-commission-call-for-evidence/
#
# NESO: https://www.linkedin.com/posts/julian-leslie-b9059535_strategicenergyplanning-wholesystem-energytransition-share-7440317825442938881-qEfk/?utm_source=share&utm_medium=member_android&rcm=ACoAAC8B12kB8C7fEa90uFc21XKWd4cJMbM6VSI
#
# Transnet BW: EU grid package: power brief: https://www.linkedin.com/posts/ana-carolina-burghi_the-power-brief-ugcPost-7442524257273712640-Z78s/?utm_source=share&utm_medium=member_desktop&rcm=ACoAAC8B12kB8C7fEa90uFc21XKWd4cJMbM6VSI
#
# 4 TSO statement: https://www.linkedin.com/posts/ana-carolina-burghi_position-on-the-grids-package-ugcPost-7439224682387513344-s5Xr?utm_source=share&utm_medium=member_desktop&rcm=ACoAAC8B12kB8C7fEa90uFc21XKWd4cJMbM6VSI

# %% [markdown]
# other institutions: DLR, TNO, universities, Jülich, ACER, ENTSO-E, JRC, NREL, EIA, CSIRO, IRENA, IEA,

# %% [markdown]
# IRENA Energy taxonomy: https://www.irena.org/Publications/2024/Mar/Energy-taxonomy-Classifications-for-the-energy-transition
#
# IRENA Renewable capacity statisitics 2026: https://www.irena.org/Publications/2026/Mar/Renewable-capacity-statistics-2026
#
# IRENA renewable power generation costs in 2024: https://www.irena.org/Publications/2025/Jun/Renewable-Power-Generation-Costs-in-2024
